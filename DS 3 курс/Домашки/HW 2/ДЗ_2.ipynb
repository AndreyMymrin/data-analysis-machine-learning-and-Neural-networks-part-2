# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_mipt.html">Phystech@DataScience</a>
# ## Домашнее задание 2
#
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_pds_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате `ipynb`.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * **Код из рассказанных на занятиях ноутбуков можно использовать без ограничений.**
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив,
#     * отправив ее как файл боту вместе с ноутбуком *или*
#     * вставив ее в ноутбук посредством `Edit -> Insert Image` (<font color="red">фото, вставленные ссылкой, не принимаются</font>);
#   * в виде $\LaTeX$ в markdown-ячейках.
# * Решения не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта (вставки фото в ноутбук). <font color="red"><b>Неправильно вставленные фотографии могут не передаться при отправке.</b></font> Для проверки попробуйте переместить `ipynb` в другую папку и открыть его там.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
# **Баллы за задание:**
#
# * Задача 1 &mdash;  80 баллов
# * Задача 2 &mdash;  30 баллов
#
#
#
#
# -----

# %%
# Bot check

# HW_ID: phds_hw2
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: not final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %% [markdown]
# ## Сверточные сети
#
# В этой домашней работе вам предстоит построить сверточную сеть для классификации изображений.
#
# #### Биология
# Необходимо классифицировать изображения МРТ головного мозга из датасета [**"Brain Tumor Classification (MRI)"**](https://www.kaggle.com/datasets/sartajbhuvaji/brain-tumor-classification-mri) и определить вид опухоли.
#
# #### Физика
# Необходимо классифицировать изображения солнечного затмения из датасета [**"Solar Eclipse Classification"**](https://www.kaggle.com/datasets/tshr147/solar-eclipse-classification) по степени: частичное, полное и кольцевое.

# %% [markdown]
# ### Задача 1.

# %% [markdown]
# **Пожалуйста, ПРОЧИТАЙТЕ ВНИМАТЕЛЬНО то, что написано ниже, там изложены требования к вашей работе и полезные советы!**
#
#
# **Требование к работе**
#
# * **Запрещено** использовать предобученные нейросети.
#
# * **Запрещено** использовать тестовые данные где-либо за исключением вычисления финальной оценки качества. Подсказка &mdash; распределение данных на тесте такое же как в тестовых данных.
#
#
# ### Советы
#
# #### Архитектура нейросети
# * В отличие от семинара в данном датасете могут встретиться картинки разных размеров. Эту проблему можно решить двумя способами:
#   - Используя `torchvision.transforms.Resize` можно привести картинки к единому размеру. Если вы решите использовать этот способ, стоит посмотреть, какого в принципе размера встречаются картинки, чтобы не сжать их слишком сильно. Для картинок одного размера можно обучить бейзлайн в виде полносвязной сети.
#   - Учесть переменный размер картинки в архитектуре сети. Общий принцип здесь такой: можно использовать свертки с нужным `padding`, чтобы не иметь проблем из-за уменьшения размеров картинки из-за сверток, последовательно применяя сверточные слои и пуллинги, нужно увеличивать количество каналов одновременно с уменьшением размера картинок (из-за пуллинга), а в конце, получив картинку размера (n_channels, nx, ny), оставить вектор размера (n_channels) (n_channels будет одинаковым для всех картинок, поскольку зависит от архитектуры сети!). Сделать это можно усреднением по пространственным картам [torch.nn.AdaptiveAvgPool2d](https://pytorch.org/docs/stable/generated/torch.nn.AdaptiveAvgPool2d.html).
# * Попробуйте разные размеры фильтров, страйдинг, паддинг
# * Также можно попробовать разные активации: `tanh`, `leaky relu` и другие.
#
# #### Процесс обучения
# * Воспользуйтесь GPU google colab или любой другой GPU, которая у вас есть.
# * Для сокращения вычислительной сложности можно поэксперементировать с параметром `stride`. Кроме того можете попробовать разные виды Poooling-ов.
# * Помните, что некоторым нейросетям требуется $10$ эпох, чтобы сойтись, а некоторым – $500$. Большие нейросети дольше обучаются.
# * Если вы достигли какого-то порога на валидации лучше подождать примерно 10 эпох перед тем как останавливать обучение.
#
# #### И главное:
# * Рисуйте кривые обучения: loss и метрика качества (лучше использовать F1-меру) для обучения и валидации.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil

import torch
from torch import nn
import torchvision
from torchvision import transforms
from sklearn.metrics import f1_score
from sklearn.utils.random import sample_without_replacement
from IPython.display import Image, clear_output
from collections import defaultdict
from torch.optim import lr_scheduler
from matplotlib.animation import FuncAnimation, ImageMagickFileWriter
import time

# %matplotlib inline

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(device)
# Out:
# cpu

# %% [markdown]
# ### Для Google Colab
# Чтобы не грузить данные каждый раз в колаб при его отключении, а данные сюда грузятся небыстро, будет лучше всего поступить следующим образом.
# * Загрузите архив на диск.
# * Примонтируйте ваш диск к данному ноутбуку с помощью кода ниже

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * В панели слева ("Файлы") откройте папку `drive/MyDrive/..` и найдите архив с файлом на диске
# * Кликните по файлу и нажмите на кнопку "Скопировать путь"
#
# Теперь вы можете обратиться к данным, используя скопированный путь

# %%
# Путь до диска (для напоминания)
DISK_PATH = "drive/MyDrive"
# Путь до архива с данными (пример)
ZIP_PATH = "/content/drive/MyDrive/archive.zip"
# Путь для папки с данными
DATA_PATH = "/content"

# %% [markdown]
# * Разархивируйете данные на диске.

# %%
! unzip $ZIP_PATH -d  $DATA_PATH;
# Out:
# Archive:  /content/drive/MyDrive/archive.zip
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7711.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7722.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7748.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7755.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7761.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7775.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7800.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7819.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7825.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7835.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7845.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7849.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7857.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7862.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7874.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7883.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7888.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7890.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7898.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7908.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7917.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7944.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7945.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7949.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7963.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7977.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_7999.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8004.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8027.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8053.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8061.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8073.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8078.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8082.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8087.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8089.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8092.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8119.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8122.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8127.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8130.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8146.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8168.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8170.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8183.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8187.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8191.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8195.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8207.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8217.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8247.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8257.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8273.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8289.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8310.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8316.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8351.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8357.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8368.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8379.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8399.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8414.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8433.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8436.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8454.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8469.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8479.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8496.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8524.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8532.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8564.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8585.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8597.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8606.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8610.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8623.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8630.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8650.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8652.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8660.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8694.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8704.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8706.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8707.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8723.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8742.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8765.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8766.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8768.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8773.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8781.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8784.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8789.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8793.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8798.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8812.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8826.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8849.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8857.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8858.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8864.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8875.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8878.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8889.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8930.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8933.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8942.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8963.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8966.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8981.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8996.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_8998.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9072.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9078.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9094.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9133.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9137.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9146.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9167.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9176.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9180.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9210.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9211.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9216.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9223.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9227.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9234.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9237.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9244.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9257.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9267.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9268.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9294.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9302.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9327.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9339.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9343.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9346.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9360.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9374.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9376.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9378.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9383.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9399.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9405.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9410.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9431.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9472.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9482.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9490.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9503.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9505.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9522.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9531.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9547.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9552.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9560.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9564.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9566.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9574.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9577.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9615.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9628.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9630.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9631.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9635.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9653.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9664.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9670.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9692.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9709.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9731.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9745.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9761.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9779.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9803.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9863.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9906.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9909.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9914.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9917.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9931.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9953.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9986.jpeg
#   inflating: /content/Test/Annular_solar_eclipse/Augmented_0__0_9992.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7764.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7765.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7770.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7774.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7782.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7784.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7786.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7797.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7798.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7812.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7831.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7832.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7852.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7855.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7869.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7873.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7891.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7895.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7896.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7916.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7930.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7939.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7947.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7964.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7968.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7976.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_7996.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8003.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8006.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8013.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8014.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8016.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8044.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8076.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8091.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8093.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8102.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8119.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8121.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8122.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8127.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8136.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8142.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8157.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8160.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8176.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8180.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8181.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8185.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8194.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8198.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8201.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8206.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8226.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8227.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8233.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8251.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8266.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8269.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8293.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8296.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8302.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8306.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8315.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8320.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8334.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8344.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8351.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8353.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8359.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8360.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8374.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8376.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8378.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8385.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8389.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8397.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8409.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8420.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8424.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8433.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8447.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8449.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8451.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8468.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8481.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8483.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8494.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8498.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8527.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8532.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8534.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8542.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8551.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8555.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8559.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8570.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8585.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8591.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8593.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8599.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8626.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8639.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8655.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8661.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8672.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8678.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8688.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8709.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8710.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8713.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8718.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8730.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8735.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8740.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8749.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8777.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8778.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8782.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8789.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8797.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8802.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8806.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8811.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8824.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8843.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8854.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8892.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8904.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8905.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8906.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8907.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8958.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8962.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8964.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8967.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8968.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8977.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_8979.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9001.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9002.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9003.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9008.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9020.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9022.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9026.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9056.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9057.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9062.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9063.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9074.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9086.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9098.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9099.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9140.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9142.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9143.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9145.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9146.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9147.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9162.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9165.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9174.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9184.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9188.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9193.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9196.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9199.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9203.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9217.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9221.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9236.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9242.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9253.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9262.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9303.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9321.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9345.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9361.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9368.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9372.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9378.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9382.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9392.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9393.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9421.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9427.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9429.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9438.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9456.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9476.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9480.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9486.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9495.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9499.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9507.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9519.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9523.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9537.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9540.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9551.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9562.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9567.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9581.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9596.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9605.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9647.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9665.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9687.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9702.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9705.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9719.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9738.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9749.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9759.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9771.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9783.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9819.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9826.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9845.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9847.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9849.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9865.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9872.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9877.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9899.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9903.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9906.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9917.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9921.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9925.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9930.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9932.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9939.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9943.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9948.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9951.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9954.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9959.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9965.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9973.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9997.jpeg
#   inflating: /content/Test/Partial_solar_eclipse/Augmented_0__0_9998.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7757.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7774.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7776.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7783.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7790.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7823.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7827.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7857.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7865.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7875.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7883.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7896.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7907.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7912.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7917.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7923.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7939.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7969.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7973.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_7993.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8004.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8063.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8067.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8114.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8121.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8133.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8140.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8149.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8163.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8185.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8193.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8211.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8229.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8237.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8246.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8261.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8264.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8276.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8309.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8332.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8342.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8365.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8366.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8374.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8377.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8378.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8384.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8386.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8411.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8425.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8449.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8455.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8460.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8471.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8477.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8495.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8503.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8511.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8525.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8560.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8561.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8567.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8580.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8581.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8582.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8586.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8588.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8591.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8592.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8597.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8627.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8645.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8648.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8658.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8670.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8684.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8688.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8708.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8711.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8733.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8741.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8755.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8762.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8783.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8789.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8802.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8810.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8811.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8827.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8834.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8841.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8849.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8854.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8887.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8912.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8931.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8935.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8967.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8978.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8986.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8992.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_8995.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9022.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9025.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9027.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9050.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9056.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9068.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9078.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9091.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9093.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9096.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9112.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9119.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9130.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9139.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9140.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9141.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9143.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9155.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9157.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9178.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9197.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9208.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9218.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9227.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9234.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9241.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9256.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9294.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9295.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9321.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9323.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9327.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9359.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9362.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9405.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9418.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9428.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9429.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9432.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9433.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9435.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9447.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9464.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9465.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9470.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9488.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9502.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9524.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9530.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9555.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9556.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9557.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9563.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9567.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9571.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9580.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9594.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9598.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9601.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9614.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9618.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9620.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9629.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9637.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9641.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9646.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9654.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9694.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9701.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9705.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9710.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9712.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9720.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9723.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9740.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9762.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9770.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9779.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9782.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9797.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9800.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9827.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9837.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9846.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9849.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9850.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9872.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9877.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9893.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9897.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9909.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9912.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9921.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9934.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9941.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9942.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9944.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9949.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9974.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9981.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9991.jpeg
#   inflating: /content/Test/Total_Solar_Eclipse/Augmented_0__0_9993.jpeg
#   inflating: /content/Train/Annular_solar_eclipse/1.jpg
#   inflating: /content/Train/Annular_solar_eclipse/10.jpg
#   inflating: /content/Train/Annular_solar_eclipse/11.jpg
#   inflating: /content/Train/Annular_solar_eclipse/12.jpg
#   inflating: /content/Train/Annular_solar_eclipse/13.jpg
# ...
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5758.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5762.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_58.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_583.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5837.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_585.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5862.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5865.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5899.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5908.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5917.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5924.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5930.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5939.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5940.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5941.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5948.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5959.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5961.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5964.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5966.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5973.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5979.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_598.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5980.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5985.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5987.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_5989.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_599.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6014.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6017.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6024.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6036.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6048.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6050.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6057.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6095.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6096.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6107.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_611.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_613.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6131.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6137.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6148.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6179.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6195.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6210.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6222.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6238.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_625.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6265.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6271.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6277.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6292.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6301.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6316.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6325.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6357.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6377.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6378.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6381.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6392.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_641.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_642.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6420.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6425.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6435.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_644.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6471.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6472.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6485.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6506.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6515.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6516.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6519.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6548.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6552.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6567.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_658.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6602.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6607.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6656.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_666.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_667.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_669.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6699.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6711.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6715.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6733.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6739.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6754.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6755.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6756.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6771.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_678.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6786.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6793.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6798.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6799.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6803.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_681.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6823.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6841.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6843.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6846.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6876.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6878.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6880.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6929.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6931.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6955.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6978.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6981.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6982.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_699.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_6991.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7011.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7017.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7026.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7036.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7039.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_704.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7041.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_706.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7072.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7113.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7130.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7134.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7147.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7200.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7213.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7244.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7249.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_725.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7255.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_726.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7264.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7276.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7281.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7282.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7287.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7299.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_73.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7302.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7309.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7312.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7316.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7325.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7344.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7350.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7352.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7353.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7357.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7359.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7368.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_737.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7370.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7391.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7414.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7422.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7480.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7481.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7482.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7498.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7508.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_751.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7511.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7513.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7526.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7528.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7540.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7541.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7599.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7604.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7607.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7616.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_763.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7632.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7643.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7653.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7691.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_77.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_771.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7716.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7719.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7720.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7723.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7740.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_7754.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_780.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_792.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_795.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_799.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_8.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_811.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_812.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_813.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_821.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_823.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_826.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_835.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_860.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_868.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_878.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_882.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_896.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_90.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_928.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_971.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_976.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_980.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_989.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_99.jpeg
#   inflating: /content/Train/Total_solar_eclipse/Augmented_0__0_999.jpeg

# %%
DATA_PATH = os.path.join(DATA_PATH, '')

# %% [markdown]
# В папке `DATA_PATH` теперь хранится папка с тренировочными данными (у биологов - `Training`, у физиков - `Train`) и тестовыми (у биологов - `Testing`, у физиков - `Test`). В папку с тестовыми данными не подглядывать :)

# %%
! ls $DATA_PATH
# Out:
# drive  sample_data  Test  Train

# %% [markdown]
# ### Подготовка датасетов

# %% [markdown]
# ### Физика
# В `train` датасете $3$ вида солнечного затмения и $2214$ изображений Солнца (объектов). Посмотрим на какую-нибудь картину из набора данных.

# %%
path_to_img = os.path.join(DATA_PATH, "Train/Annular_solar_eclipse/Augmented_0__0_955.jpeg")
image = plt.imread(path_to_img)
plt.figure(figsize=(12, 5))
plt.imshow(image)
plt.axis("off");

# %%
from PIL import Image
with Image.open(path_to_img) as img:
    width, height = img.size
print(width, ' ', height)
# Out:
# 282   179

# %%
from os import listdir

path = os.path.join(DATA_PATH, "Train/Annular_solar_eclipse/")
imagesList = listdir(path)
loadedImages = []

for image in imagesList:
    img = Image.open(path + image)
    loadedImages.append(img)

imgs = loadedImages

# %%
for img in imgs:
  print(img.size)
# Out:
# (275, 183)
# (225, 225)
# (318, 159)
# (300, 168)
# (369, 137)
# (300, 168)
# (275, 183)
# (275, 183)
# (275, 183)
# (259, 194)
# (300, 168)
# (259, 194)
# (275, 183)
# (275, 183)
# (259, 194)
# (301, 167)
# (259, 194)
# (259, 194)
# (259, 194)
# (282, 179)
# (259, 194)
# (225, 225)
# (225, 225)
# (300, 168)
# (225, 225)
# (275, 183)
# (266, 190)
# (275, 183)
# (282, 179)
# (301, 167)
# (259, 194)
# (259, 194)
# (259, 194)
# (259, 194)
# (300, 168)
# (259, 194)
# (301, 167)
# (318, 159)
# (282, 179)
# (259, 194)
# (275, 183)
# (282, 179)
# (239, 211)
# (259, 194)
# (282, 179)
# (259, 194)
# (300, 168)
# (318, 159)
# (266, 190)
# (275, 183)
# (275, 183)
# (259, 194)
# (300, 168)
# (259, 194)
# (225, 225)
# (275, 183)
# (300, 168)
# (239, 211)
# (275, 183)
# (266, 190)
# (239, 211)
# (259, 194)
# (369, 137)
# (301, 167)
# (369, 137)
# (259, 194)
# (300, 168)
# (369, 137)
# (282, 179)
# (275, 183)
# (275, 183)
# (259, 194)
# (282, 179)
# (300, 168)
# (275, 183)
# (301, 167)
# (275, 183)
# (300, 168)
# (259, 194)
# (300, 168)
# (318, 159)
# (259, 194)
# (225, 225)
# (275, 183)
# (259, 194)
# (275, 183)
# (259, 194)
# (225, 225)
# (259, 194)
# (318, 159)
# (239, 211)
# (225, 225)
# (301, 167)
# (259, 194)
# (259, 194)
# (259, 194)
# (275, 183)
# (239, 211)
# (266, 190)
# (239, 211)
# (259, 194)
# (225, 225)
# (259, 194)
# (275, 183)
# (266, 190)
# (301, 167)
# (318, 159)
# (369, 137)
# (275, 183)
# (300, 168)
# (259, 194)
# (239, 211)
# (266, 190)
# (282, 179)
# (275, 183)
# (259, 194)
# (275, 183)
# (301, 167)
# (259, 194)
# (259, 194)
# (275, 183)
# (259, 194)
# (300, 168)
# (259, 194)
# (275, 183)
# (318, 159)
# (275, 183)
# (369, 137)
# (266, 190)
# (259, 194)
# (225, 225)
# (259, 194)
# (239, 211)
# (275, 183)
# (259, 194)
# (275, 183)
# (259, 194)
# (239, 211)
# (300, 168)
# (275, 183)
# (369, 137)
# (369, 137)
# (318, 159)
# (300, 168)
# (300, 168)
# (275, 183)
# (266, 190)
# (275, 183)
# (275, 183)
# (300, 168)
# (266, 190)
# (259, 194)
# (225, 225)
# (259, 194)
# (300, 168)
# (300, 168)
# (282, 179)
# (318, 159)
# (225, 225)
# (266, 190)
# (300, 168)
# (239, 211)
# (318, 159)
# (259, 194)
# (275, 183)
# (275, 183)
# (266, 190)
# (259, 194)
# (275, 183)
# (275, 183)
# (300, 168)
# (300, 168)
# (275, 183)
# (275, 183)
# (275, 183)
# (275, 183)
# (259, 194)
# (259, 194)
# (259, 194)
# (259, 194)
# (369, 137)
# (239, 211)
# (300, 168)
# (300, 168)
# (300, 168)
# (275, 183)
# (275, 183)
# (318, 159)
# (369, 137)
# (275, 183)
# (300, 168)
# (275, 183)
# (369, 137)
# (275, 183)
# (275, 183)
# (300, 168)
# (275, 183)
# (275, 183)
# (225, 225)
# (300, 168)
# (300, 168)
# (282, 179)
# (300, 168)
# (369, 137)
# (282, 179)
# (266, 190)
# (282, 179)
# (300, 168)
# (225, 225)
# (259, 194)
# (259, 194)
# (301, 167)
# (259, 194)
# (275, 183)
# (275, 183)
# (259, 194)
# (275, 183)
# (266, 190)
# (275, 183)
# (259, 194)
# (275, 183)
# (282, 179)
# (300, 168)
# (369, 137)
# (369, 137)
# (318, 159)
# (300, 168)
# (275, 183)
# (300, 168)
# (369, 137)
# (300, 168)
# (318, 159)
# (275, 183)
# (275, 183)
# (275, 183)
# (301, 167)
# (282, 179)
# (275, 183)
# (301, 167)
# (300, 168)
# (259, 194)
# (275, 183)
# (225, 225)
# (259, 194)
# (266, 190)
# (259, 194)
# (239, 211)
# (259, 194)
# (225, 225)
# (239, 211)
# (301, 167)
# (275, 183)
# (259, 194)
# (259, 194)
# (225, 225)
# (300, 168)
# (282, 179)
# (369, 137)
# (259, 194)
# (266, 190)
# (369, 137)
# (259, 194)
# (300, 168)
# (300, 168)
# (259, 194)
# (275, 183)
# (300, 168)
# (275, 183)
# (300, 168)
# (282, 179)
# (266, 190)
# (259, 194)
# (275, 183)
# (369, 137)
# (301, 167)
# (275, 183)
# (282, 179)
# (275, 183)
# (300, 168)
# (275, 183)
# (259, 194)
# (259, 194)
# (318, 159)
# (282, 179)
# (225, 225)
# (300, 168)
# (275, 183)
# (369, 137)
# (275, 183)
# (239, 211)
# (239, 211)
# (300, 168)
# (301, 167)
# (275, 183)
# (369, 137)
# (259, 194)
# (300, 168)
# (275, 183)
# (275, 183)
# (318, 159)
# (259, 194)
# (266, 190)
# (259, 194)
# (275, 183)
# (300, 168)
# (239, 211)
# (318, 159)
# (259, 194)
# (369, 137)
# (282, 179)
# (300, 168)
# (318, 159)
# (300, 168)
# (282, 179)
# (282, 179)
# (318, 159)
# (300, 168)
# (275, 183)
# (282, 179)
# (266, 190)
# (275, 183)
# (318, 159)
# (282, 179)
# (301, 167)
# (259, 194)
# (239, 211)
# (301, 167)
# (282, 179)
# (275, 183)
# (275, 183)
# (301, 167)
# (282, 179)
# (300, 168)
# (318, 159)
# (282, 179)
# (259, 194)
# (275, 183)
# (300, 168)
# (282, 179)
# (301, 167)
# (300, 168)
# (259, 194)
# (300, 168)
# (225, 225)
# (369, 137)
# (301, 167)
# (318, 159)
# (259, 194)
# (300, 168)
# (259, 194)
# (275, 183)
# (275, 183)
# (300, 168)
# (318, 159)
# (300, 168)
# (275, 183)
# (301, 167)
# (301, 167)
# (282, 179)
# (259, 194)
# (259, 194)
# (275, 183)
# (369, 137)
# (369, 137)
# (239, 211)
# (259, 194)
# (225, 225)
# (275, 183)
# (275, 183)
# (300, 168)
# (275, 183)
# (266, 190)
# (300, 168)
# (300, 168)
# (259, 194)
# (259, 194)
# (275, 183)
# (259, 194)
# (259, 194)
# (239, 211)
# (300, 168)
# (275, 183)
# (266, 190)
# (266, 190)
# (301, 167)
# (275, 183)
# (300, 168)
# (275, 183)
# (259, 194)
# (275, 183)
# (275, 183)
# (300, 168)
# (275, 183)
# (369, 137)
# (300, 168)
# (282, 179)
# (266, 190)
# (259, 194)
# (300, 168)
# (259, 194)
# (239, 211)
# (275, 183)
# (300, 168)
# (259, 194)
# (301, 167)
# (259, 194)
# (300, 168)
# (318, 159)
# (369, 137)
# (369, 137)
# (225, 225)
# (282, 179)
# (259, 194)
# (282, 179)
# (259, 194)
# (259, 194)
# (275, 183)
# (300, 168)
# (300, 168)
# (266, 190)
# (300, 168)
# (300, 168)
# (318, 159)
# (259, 194)
# (275, 183)
# (275, 183)
# (225, 225)
# (225, 225)
# (300, 168)
# (275, 183)
# (300, 168)
# (301, 167)
# (318, 159)
# (300, 168)
# (259, 194)
# (301, 167)
# (275, 183)
# (318, 159)
# (300, 168)
# (318, 159)
# (259, 194)
# (259, 194)
# (275, 183)
# (369, 137)
# (369, 137)
# (239, 211)
# (239, 211)
# (275, 183)
# (275, 183)
# (275, 183)
# (275, 183)
# (369, 137)
# (300, 168)
# (259, 194)
# (275, 183)
# (259, 194)
# (300, 168)
# (318, 159)
# (369, 137)
# (318, 159)
# (301, 167)
# (259, 194)
# (259, 194)
# (300, 168)
# (300, 168)
# (300, 168)
# (300, 168)
# (275, 183)
# (369, 137)
# (275, 183)
# (275, 183)
# (300, 168)
# (300, 168)
# (259, 194)
# (300, 168)
# (225, 225)
# (300, 168)
# (259, 194)
# (275, 183)
# (275, 183)
# (300, 168)
# (282, 179)
# (369, 137)
# (259, 194)
# (275, 183)
# (225, 225)
# (259, 194)
# (266, 190)
# (259, 194)
# (300, 168)
# (300, 168)
# (266, 190)
# (266, 190)
# (275, 183)
# (275, 183)
# (275, 183)
# (275, 183)
# (318, 159)
# (301, 167)
# (282, 179)
# (300, 168)
# (259, 194)
# (266, 190)
# (259, 194)
# (259, 194)
# (300, 168)
# (259, 194)
# (259, 194)
# (301, 167)
# (300, 168)
# (225, 225)
# (369, 137)
# (300, 168)
# (259, 194)
# (259, 194)
# (275, 183)
# (301, 167)
# (259, 194)
# (275, 183)
# (259, 194)
# (318, 159)
# (301, 167)
# (300, 168)
# (225, 225)
# (282, 179)
# (318, 159)
# (318, 159)
# (275, 183)
# (275, 183)
# (259, 194)
# (300, 168)
# (301, 167)
# (300, 168)
# (266, 190)
# (275, 183)
# (266, 190)
# (259, 194)
# (259, 194)
# (239, 211)
# (259, 194)
# (300, 168)
# (225, 225)
# (275, 183)
# (301, 167)
# (275, 183)
# (259, 194)
# (275, 183)
# (275, 183)
# (259, 194)
# (300, 168)
# (275, 183)
# (225, 225)
# (259, 194)
# (259, 194)
# (301, 167)
# (300, 168)
# (259, 194)
# (275, 183)
# (259, 194)
# (275, 183)
# (259, 194)
# (259, 194)
# (259, 194)
# (369, 137)
# (275, 183)
# (300, 168)
# (259, 194)
# (275, 183)
# (318, 159)
# (275, 183)
# (275, 183)
# (259, 194)
# (301, 167)
# (300, 168)
# (275, 183)
# (301, 167)
# (300, 168)
# (259, 194)
# (239, 211)
# (259, 194)
# (275, 183)
# (300, 168)
# (300, 168)
# (259, 194)
# (259, 194)
# (300, 168)
# (275, 183)
# (282, 179)
# (275, 183)
# (318, 159)
# (259, 194)
# (266, 190)
# (282, 179)
# (259, 194)
# (239, 211)
# (266, 190)
# (266, 190)
# (275, 183)
# (301, 167)
# (275, 183)
# (259, 194)
# (225, 225)
# (275, 183)
# (301, 167)
# (225, 225)
# (275, 183)
# (259, 194)
# (225, 225)
# (275, 183)
# (300, 168)
# (239, 211)
# (275, 183)
# (275, 183)
# (275, 183)
# (318, 159)
# (301, 167)
# (369, 137)
# (318, 159)
# (300, 168)
# (259, 194)
# (259, 194)
# (275, 183)
# (259, 194)
# (259, 194)
# (266, 190)
# (282, 179)
# (301, 167)
# (266, 190)
# (275, 183)
# (259, 194)
# (225, 225)
# (259, 194)
# (301, 167)
# (259, 194)
# (300, 168)
# (275, 183)
# (282, 179)
# (318, 159)
# (225, 225)
# (300, 168)
# (275, 183)
# (259, 194)
# (275, 183)
# (369, 137)
# (275, 183)
# (301, 167)
# (301, 167)
# (300, 168)
# (369, 137)
# (300, 168)
# (225, 225)
# (282, 179)
# (239, 211)
# (239, 211)
# (300, 168)
# (259, 194)
# (301, 167)
# (266, 190)
# (259, 194)
# (259, 194)
# (225, 225)
# (275, 183)
# (300, 168)
# (369, 137)
# (259, 194)
# (275, 183)
# (301, 167)
# (259, 194)
# (300, 168)
# (300, 168)
# (300, 168)
# (318, 159)
# (275, 183)
# (275, 183)
# (275, 183)
# (259, 194)
# (259, 194)
# (259, 194)
# (259, 194)
# (239, 211)
# (275, 183)
# (259, 194)
# (318, 159)
# (266, 190)
# (300, 168)
# (300, 168)
# (275, 183)
# (225, 225)
# (369, 137)
# (225, 225)
# (282, 179)
# (259, 194)
# (266, 190)
# (259, 194)
# (282, 179)
# (239, 211)
# (259, 194)
# (275, 183)
# (275, 183)
# (259, 194)
# (275, 183)
# (259, 194)
# (300, 168)
# (259, 194)

# %% [markdown]
# Размеры и вправду разные :(

# %% [markdown]
# Разобьем `train` выборку на `train` и `val`:

# %%
# Папка со всеми фотографиями / папка с фотографиями для тренировки
TRAIN_DIR = os.path.join(DATA_PATH, "Train")
# Считываем названия директорий, которые и являются видом затмения
ECLIPSE_LIST = {i:name for i, name in enumerate(os.listdir(TRAIN_DIR))}


# Папка с фотографиями для валидации
VAL_DIR = os.path.join(DATA_PATH, "val")
os.makedirs(VAL_DIR, exist_ok=True)

# Папка с фотографиями для теста
TEST_DIR = os.path.join(DATA_PATH, "Test")


# Доля изображений в валидации
VAL_FRAC = 0.3


# Создаем директорию с валидационной выборкой для каждого вида затмения.
for eclipse in ECLIPSE_LIST.values():
    os.makedirs(os.path.join(VAL_DIR, eclipse), exist_ok=True)

    # Считываем выборку изображений.
    eclipse_path = os.path.join(TRAIN_DIR, eclipse)

    # Сортируем изображения для детерминированнсти
    images_filename = sorted(os.listdir(eclipse_path))

    # Выделяем часть изображений для валидации
    # Выбираем случайные изображения из выборки для валидции, с установленным random_state
    num_images = len(images_filename)
    num_val = int(num_images * VAL_FRAC)
    indices = sample_without_replacement(num_images, num_val, random_state=42)
    val_images = np.take(images_filename, indices)

    print(f'{eclipse} | train images = {num_images - num_val} | val images = {num_val}')

    # Сохраняем валидационную выборку
    for image_filename in val_images:
        source = os.path.join(TRAIN_DIR, eclipse, image_filename)
        destination = os.path.join(VAL_DIR, eclipse, image_filename)
        shutil.copy(source, destination)
        os.remove(source)
# Out:
# Annular_solar_eclipse | train images = 493 | val images = 211
# Partial_solar_eclipse | train images = 543 | val images = 232
# Total_solar_eclipse | train images = 515 | val images = 220

# %% [markdown]
# Убедимся еще раз, что в папке train и val все разложено по папкам-классам (авторам). Эта структура папок важна для использования классов PyTorch по работе с данными (`ImageFolder` и `DataLoader`):

# %%
# !ls $TRAIN_DIR
# Out:
# Annular_solar_eclipse  Partial_solar_eclipse  Total_solar_eclipse

# %%
# !ls $VAL_DIR
# Out:
# Annular_solar_eclipse  Partial_solar_eclipse  Total_solar_eclipse

# %%
resize_and_crop = transforms.Compose([
   transforms.Resize(size = (200,300)),
   transforms.ToTensor()
])
dataset = torchvision.datasets.ImageFolder(root=TRAIN_DIR, transform=resize_and_crop)

# %%
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1551
#     Root location: /content/Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(200, 300), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#            )

# %%
train_dataset = torchvision.datasets.ImageFolder(TRAIN_DIR, transform=resize_and_crop)
val_dataset = torchvision.datasets.ImageFolder(VAL_DIR, transform=resize_and_crop)

# %%
train_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1551
#     Root location: /content/Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(200, 300), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#            )

# %% [markdown]
# ### I. Построение сверточных сетей с использованием Dropout и BatchNorm
#
# В первой части задания вам предстоит сравнить четыре различные реализации одной и той же сверточной сети. Для реализации сети можете смело использовать код с семинара.

# %%
def plot_learning_curves(history):


    '''
    Функция для вывода лосса и метрики во время обучения.

    :param history: (dict)
        accuracy и loss на обучении и валидации
    '''
    # sns.set_style(style='whitegrid')
    fig = plt.figure(figsize=(20, 7))

    plt.subplot(1,2,1)
    plt.title('Лосс', fontsize=15)
    plt.plot(history['loss']['train'], label='train')
    plt.plot(history['loss']['val'], label='val')
    plt.ylabel('лосс', fontsize=15)
    plt.xlabel('эпоха', fontsize=15)
    plt.legend()

    plt.subplot(1,2,2)
    plt.title('Точность', fontsize=15)
    plt.plot(history['acc']['train'], label='train')
    plt.plot(history['acc']['val'], label='val')
    plt.ylabel('лосс', fontsize=15)
    plt.xlabel('эпоха', fontsize=15)
    plt.legend()
    plt.show()

# %%
def train(
    model,
    criterion,
    optimizer,
    train_batch_gen,
    val_batch_gen,
    num_epochs=50
):
    '''
    Функция для обучения модели и вывода лосса и метрики во время обучения.

    :param model: обучаемая модель
    :param criterion: функция потерь
    :param optimizer: метод оптимизации
    :param train_batch_gen: генератор батчей для обучения
    :param val_batch_gen: генератор батчей для валидации
    :param num_epochs: количество эпох

    :return: обученная модель
    :return: (dict) accuracy и loss на обучении и валидации ("история" обучения)
    '''

    history = defaultdict(lambda: defaultdict(list))

    for epoch in range(num_epochs):
        train_loss = 0
        train_acc = 0
        val_loss = 0
        val_acc = 0

        start_time = time.time()

        # Устанавливаем поведение dropout / batch_norm  в обучение
        model.train(True)

        # На каждой "эпохе" делаем полный проход по данным
        for X_batch, y_batch in train_batch_gen:
            # Обучаемся на батче (одна "итерация" обучения нейросети)
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            # Логиты на выходе модели
            logits = model(X_batch)

            # Подсчитываем лосс
            loss = criterion(logits, y_batch.long().to(device))

            # Обратный проход
            loss.backward()
            # Шаг градиента
            optimizer.step()
            # Зануляем градиенты
            optimizer.zero_grad()

            # Сохраяняем лоссы и точность на трейне
            train_loss += loss.detach().cpu().numpy()
            y_pred = logits.max(1)[1].detach().cpu().numpy()
            train_acc += np.mean(y_batch.cpu().numpy() == y_pred)

        # Подсчитываем лоссы и сохраням в "историю"
        train_loss /= len(train_batch_gen)
        train_acc /= len(train_batch_gen)
        history['loss']['train'].append(train_loss)
        history['acc']['train'].append(train_acc)

        # Устанавливаем поведение dropout / batch_norm в режим тестирования
        model.train(False)

        # Полный проход по валидации
        for X_batch, y_batch in val_batch_gen:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            # Логиты, полученные моделью
            logits = model(X_batch)

            # Лосс на валидации
            loss = criterion(logits, y_batch.long().to(device))

            # Сохраяняем лоссы и точность на валидации
            val_loss += loss.detach().cpu().numpy()
            y_pred = logits.max(1)[1].detach().cpu().numpy()
            val_acc += np.mean(y_batch.cpu().numpy() == y_pred)

        # Подсчитываем лоссы и сохраням в "историю"
        val_loss /= len(val_batch_gen)
        val_acc /= len(val_batch_gen)
        history['loss']['val'].append(val_loss)
        history['acc']['val'].append(val_acc)

        clear_output()

        plot_learning_curves(history)

    return model, history

# %%
batch_size = 64

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen   = torch.utils.data.DataLoader(val_dataset,   batch_size=batch_size, shuffle=True)

# %% [markdown]
# 1. Постройте простую сверточную сеть без использования функций Dropout и BatchNorm.

# %%
class SimpleConvNet(nn.Module):
    def __init__(self):
        super(SimpleConvNet, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, 4)
        self.mp1 = nn.MaxPool2d(3)

        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(16, 8, 3)
        self.mp2 = nn.MaxPool2d(2)

        self.relu2 = nn.ReLU()


        self.flatten = nn.Flatten()
        self.fc3 = nn.Linear(11280, 512)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(512, 3)

    def forward(self, x):
        layer1 = self.conv1(self.mp1(x))
        layer1 = self.relu1(layer1)

        layer2 = self.mp2(self.conv2(layer1))
        layer2 = self.relu2(layer2)

        out = self.flatten(layer2)
        out = self.relu3(self.fc3(out))
        out = self.fc4(out)
        return out

# %%
model = SimpleConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005)

model, history = train(
    model, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)

# %% [markdown]
# Видны скачки loss начиная с ~37 эпохи. Я считаю, что это может быть связано с перескакиванием минимума из-за слишком высокого lr

# %% [markdown]
# 2. Попробуйте добавить BatchNorm на слои своей сверточной сети, не используя Dropout.

# %%
class ConvNetBN(nn.Module):
    def __init__(self):
        super(ConvNetBN, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, 4)
        self.mp1 = nn.MaxPool2d(3)
        self.bn1 = nn.BatchNorm2d(16)

        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(16, 8, 3)
        self.mp2 = nn.MaxPool2d(2)
        self.bn2 = nn.BatchNorm2d(8)

        self.relu2 = nn.ReLU()


        self.flatten = nn.Flatten()
        self.fc3 = nn.Linear(11280, 512)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(512, 3)

    def forward(self, x):
        layer1 = self.conv1(self.mp1(x))
        layer1 = self.relu1(self.bn1(layer1))

        layer2 = self.mp2(self.conv2(layer1))
        layer2 = self.relu2(self.bn2(layer2))

        out = self.flatten(layer2)
        out = self.relu3(self.fc3(out))
        out = self.fc4(out)
        return out

# %%
modelBN = ConvNetBN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(modelBN.parameters(), lr=0.01)

modelBN, historyBN = train(
    modelBN, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)

# %% [markdown]
# Происходит нечто странное. по точность на трейне практически 1, что свидетельствует о переобучении, но в то же время точность на валидации в пределах нормы(?!)

# %% [markdown]
# 3. Попробуйте добавить Dropout на слои своей сверточной сети, не используя BatchNorm.

# %%
class ConvNetDr(nn.Module):
    def __init__(self):
        super(ConvNetDr, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, 4)
        self.mp1 = nn.MaxPool2d(3)
        self.droupout1 = nn.Dropout(0.3)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(16, 16, 3)
        self.mp2 = nn.MaxPool2d(2)
        self.droupout2 = nn.Dropout(0.3)
        self.relu2 = nn.ReLU()

        self.flatten = nn.Flatten()
        self.fc3 = nn.Linear(23808, 512)
        self.droupout3 = nn.Dropout(0.3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(512, 3)

    def forward(self, x):
        layer1 = self.mp1(self.conv1(x))
        layer1 = self.relu1(self.droupout1(layer1))

        layer2 = self.mp2(self.conv2(layer1))
        layer2 = self.relu2(self.droupout2(layer2))

        out = self.flatten(layer2)
        out = self.relu3(self.droupout3(self.fc3(out)))
        out = self.fc4(out)
        return out

# %%
modelDr = ConvNetDr().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(modelDr.parameters(), lr=0.01)

modelDr, historyDr = train(
    modelDr, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)

# %% [markdown]
# 1 минута на 1 эпоху :(

# %% [markdown]
# 4. Теперь добавьте на все слои сети и Dropout, и BatchNorm.

# %% [markdown]
# Не успеваю обучить до дедлайна ((

# %%
class ConvNetAll(nn.Module):
    def __init__(self):
        super(ConvNetAll, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, 4)
        self.mp1 = nn.MaxPool2d(3)
        self.bn1 = nn.BatchNorm2d(16)
        self.droupout1 = nn.Dropout(0.3)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(16, 16, 3)
        self.mp2 = nn.MaxPool2d(2)
        self.bn2 = nn.BatchNorm2d(16)
        self.droupout2 = nn.Dropout(0.3)
        self.relu2 = nn.ReLU()

        self.flatten = nn.Flatten()
        self.fc3 = nn.Linear(23808, 512)
        self.droupout3 = nn.Dropout(0.3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(512, 3)

    def forward(self, x):
        layer1 = self.mp1(self.conv1(x))
        layer1 = self.relu1(self.droupout1(self.bn1(layer1)))

        layer2 = self.mp2(self.conv2(layer1))
        layer2 = self.relu2(self.droupout2(self.bn2(layer2)))

        out = self.flatten(layer2)
        out = self.relu3(self.droupout3(self.fc3(out)))
        out = self.fc4(out)
        return out

# %%
modelAll = ConvNetAll().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

modelAll, historyAll = train(
    modelAll, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-2d75eaee11d1> in <cell line: 5>()
#       3 optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
#       4
# ----> 5 modelAll, historyAll = train(
#       6     modelAll, criterion, optimizer,
#       7     train_batch_gen, val_batch_gen,
#
# <ipython-input-22-6788012db611> in train(model, criterion, optimizer, train_batch_gen, val_batch_gen, num_epochs)
#      73
#      74             # Логиты, полученные моделью
# ---> 75             logits = model(X_batch)
#      76
#      77             # Лосс на валидации
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-76-e1758e249f83> in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         layer1 = self.mp1(self.conv1(x))
#      25         layer1 = self.relu1(self.droupout1(self.bn1(layer1)))
#      26
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/pooling.py in forward(self, input)
#     164
#     165     def forward(self, input: Tensor):
# --> 166         return F.max_pool2d(input, self.kernel_size, self.stride,
#     167                             self.padding, self.dilation, ceil_mode=self.ceil_mode,
#     168                             return_indices=self.return_indices)
#
# /usr/local/lib/python3.10/dist-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     482             return if_true(*args, **kwargs)
#     483         else:
# --> 484             return if_false(*args, **kwargs)
#     485
#     486     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     780     if stride is None:
#     781         stride = torch.jit.annotate(List[int], [])
# --> 782     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     783
#     784
#
# KeyboardInterrupt:

# %% [markdown]
# Проведите сравнение построенных сверточных сетей.
#
# Для наглядности сравнения после обучения всех четырех сетей постройте общий график лосса и метрики качества на обучающей и валидационной выборках.

# %%
fig = plt.figure(figsize=(20, 7))

plt.subplot(1,2,1)
plt.title('Лосс', fontsize=15)
plt.plot(history['loss']['train'], label='train, Simple')
plt.plot(history['loss']['val'], label='val, Simple')
plt.plot(historyBN['loss']['train'], label='train, BatchNorm2d')
plt.plot(historyBN['loss']['val'], label='val, BatchNorm2d')
plt.plot(historyDr['loss']['train'], label='train, Dropout')
plt.plot(historyDr['loss']['val'], label='val, Dropout')
#plt.plot(historyAll['loss']['train'], label='train, BN + Drop')
#plt.plot(historyAll['loss']['val'], label='val, BN + Drop')
plt.ylabel('лосс', fontsize=15)
plt.xlabel('эпоха', fontsize=15)
plt.legend()



plt.subplot(1,2,2)
plt.title('Точность', fontsize=15)
plt.plot(history['acc']['train'], label='train, Simple')
plt.plot(history['acc']['val'], label='val, Simple')
plt.plot(historyBN['acc']['train'], label='train, BatchNorm2d')
plt.plot(historyBN['acc']['val'], label='val, BatchNorm2d')
plt.plot(historyDr['acc']['train'], label='train, Dropout')
plt.plot(historyDr['acc']['val'], label='val, Dropout')
#plt.plot(historyAll['acc']['train'], label='train, BN + Drop')
#plt.plot(historyAll['acc']['val'], label='val, BN + Drop')
plt.ylabel('Точность', fontsize=15)
plt.xlabel('эпоха', fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# **Вывод**

# %% [markdown]
# Лучший результат показала нейронка с BatchNorm, хоть она явно переобучилась на трейне. Простая нн и нн с дропаутом показали схожие результаты, хоть обучение второй происходило в 5 раз медленнее.
#
# Все нн показывают схожие провалы точности. моя основная гипотеза состоит в том, что lr слишком большой и коэфициенты проскакивают нужное значение. Это можно проверить дальнейшими экспериментами с оптимизаторами

# %% [markdown]
# ### II. Сравнение различных оптимизаторов
#
# Обучите несколько нейронных сетей с различными оптимизаторами. Например, можно использовать `SGD`, `rmsprop`, `adam`, `adagrad` из `torch.optim`.
#
# Проведите сравнение работы данных нейронных сетей и выберете лучший оптимизатор для вашей конкретной задачи.

# %% [markdown]
#  Буду использовать простую модель, чтобы было быстрее
#
#  SGD уже использовалось

# %%
modelAdam = SimpleConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(modelAdam.parameters(), lr=0.005)

modelAdam, historyAdam = train(
    modelAdam, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)

# %%
modelAdagrad = SimpleConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adagrad(modelAdagrad.parameters(), lr=0.005)

modelAdagrad, historyAdagrad = train(
    modelAdagrad, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)

# %%
modelRMS = SimpleConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(modelRMS.parameters(), lr=0.005)

modelRMS, historyRMS = train(
    modelRMS, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)

# %% [markdown]
# Проведите сравнение построенных сверточных сетей.
#
# Для наглядности сравнения после обучения всех сетей с различными оптимизаторами постройте общий график лосса и метрики качества на обучающей и валидационной выборках.

# %%
fig = plt.figure(figsize=(20, 7))

plt.subplot(1,2,1)
plt.title('Лосс', fontsize=15)
plt.plot(history['loss']['train'], label='train, SGD')
plt.plot(history['loss']['val'], label='val, SGD')
plt.plot(historyAdam['loss']['train'], label='train, Adam')
plt.plot(historyAdam['loss']['val'], label='val, Adam')
plt.plot(historyRMS['loss']['train'], label='train, RMS')
plt.plot(historyRMS['loss']['val'], label='val, RMS')
plt.plot(historyAdagrad['loss']['train'], label='train, Adagrad')
plt.plot(historyAdagrad['loss']['val'], label='val, Adagrad')

plt.ylabel('лосс', fontsize=15)
plt.xlabel('эпоха', fontsize=15)
plt.legend()


plt.subplot(1,2,2)
plt.title('Точность', fontsize=15)
plt.plot(history['acc']['train'], label='train, SGD')
plt.plot(history['acc']['val'], label='val, SGD')
plt.plot(historyAdam['acc']['train'], label='train, Adam')
plt.plot(historyAdam['acc']['val'], label='val, Adam')
plt.plot(historyRMS['acc']['train'], label='train, RMS')
plt.plot(historyRMS['acc']['val'], label='val, RMS')
plt.plot(historyAdagrad['acc']['train'], label='train, Adagrad')
plt.plot(historyAdagrad['acc']['val'], label='val, Adagrad')

plt.ylabel('Точность', fontsize=15)
plt.xlabel('эпоха', fontsize=15)
plt.legend()

# %% [markdown]
# **Вывод**

# %% [markdown]
# С Adam непонятно что получилось
#
# Adagred с одной стороны явное переобучение(судя по точности на трейне), а с другой - высокая точность на валидации, выше SGD
#
# RMSprop переобучение + что-то странное

# %% [markdown]
# Для лучшего оптимизатора попробуйте поварьировать значение параметров (например, `learning rate`, `momentum` и так далее). Четырех различных значений для каждого параметра будет достаточно. Сравните результаты обучения, построив аналогичные общие графики лосса и метрики качества.

# %% [markdown]
# **Вывод**

# %% [markdown]
# ### III. Способы борьбы с переобучением
#
# Мы знаем, что нейронные сети часто в какой-то момент начинают переобучаться. Есть целый набор различных способов борьбы с данным явлением.
#
# В данном пункте вам предлагается попробовать использовать две различные методики:
# `torch.optim.lr_scheduler` и `Label Smoothing`.
#
# Обучите еще две сверточные сети, пользуясь данными методами борьбы с переобучением, и сравните их результаты со своей лучшей обученной нейронной сетью из прошлого пункта.

# %% [markdown]
# **Вывод**

# %% [markdown]
# Протестируйте своё лучшее решение:

# %%
# Используйте test_dataset только для финальной оценки качества
test_dataset = ...

# %%
test_f1_score = ...

# %%
print("Итоговый результат:")
print("Test F1 score:\t\t{:.2f} %".format(test_f1_score * 100))

# %% [markdown]
# ### Задача 2.

# %% [markdown]
# На семинаре вы уже познакомились с основными методами оптимизации, которые широко используются в классическом машинном обучении. С развитием нейронных сетей и активным внедрением нейросетевого подхода, методы оптимизации стали ещё более актуальными. Но стандартные методы оптимизации, SGD и метод тяжёлого шара, имеют ряд недостатков, из-за чего их редко применяют в чистом виде. Для обучения современных нейросетей используют более продвинутые методы.
#
# В данной задаче вам предстоит самостоятельно реализовать различные оптимизаторы (запущенные из одной точки) и сравнить скорости их сходимости.
#
# Пусть задача оптимизации имеет вид $f(x) \longrightarrow \min\limits_x$, и $\nabla_{x} f(x)$ &mdash; градиент функции $f(x)$.

# %%
from IPython.display import Image, clear_output

# %%
! apt-get install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libdjvulibre-text libdjvulibre21
#   libfftw3-double3 libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0
#   libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libnetpbm10
#   libwmflite-0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng enscript gimp
#   gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance sane-utils
#   texlive-base-bin transfig ufraw-batch libfftw3-bin libfftw3-dev inkscape
#   poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts
#   imagemagick imagemagick-6-common imagemagick-6.q16 libdjvulibre-text
#   libdjvulibre21 libfftw3-double3 libgs9 libgs9-common libidn12 libijs-0.35
#   libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libnetpbm10
#   libwmflite-0.2-7 netpbm poppler-data
# 0 upgraded, 26 newly installed, 0 to remove and 18 not upgraded.
# Need to get 25.1 MB of archives.
# After this operation, 87.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6-common all 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [63.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [1,788 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickwand-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [328 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.4 [752 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.4 [5,032 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.4 [49.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.5 [3,120 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6.q16 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [224 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [14.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdjvulibre-text all 3.5.28-2build2 [50.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdjvulibre21 amd64 3.5.28-2build2 [624 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr-tools amd64 1.2~git20170615.f752187-5 [16.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwmflite-0.2-7 amd64 0.2.12-5ubuntu1 [68.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6-extra amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [70.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnetpbm10 amd64 2:10.0-15.4 [59.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 netpbm amd64 2:10.0-15.4 [1,007 kB]
# Fetched 25.1 MB in 1s (28.6 MB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../01-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../02-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../03-imagemagick-6-common_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libmagickcore-6.q16-6:amd64.
# Preparing to unpack .../04-libmagickcore-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libmagickwand-6.q16-6:amd64.
# Preparing to unpack .../05-libmagickwand-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../06-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../07-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../08-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../09-libgs9-common_9.55.0~dfsg1-0ubuntu5.4_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.4) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../10-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../11-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../12-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../13-libgs9_9.55.0~dfsg1-0ubuntu5.4_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.4) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../14-ghostscript_9.55.0~dfsg1-0ubuntu5.4_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.4) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../15-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.5_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../16-imagemagick-6.q16_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../17-imagemagick_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../18-libdjvulibre-text_3.5.28-2build2_all.deb ...
# Unpacking libdjvulibre-text (3.5.28-2build2) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../19-libdjvulibre21_3.5.28-2build2_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.28-2build2) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../20-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libjxr-tools.
# Preparing to unpack .../21-libjxr-tools_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr-tools (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libwmflite-0.2-7:amd64.
# Preparing to unpack .../22-libwmflite-0.2-7_0.2.12-5ubuntu1_amd64.deb ...
# Unpacking libwmflite-0.2-7:amd64 (0.2.12-5ubuntu1) ...
# Selecting previously unselected package libmagickcore-6.q16-6-extra:amd64.
# Preparing to unpack .../23-libmagickcore-6.q16-6-extra_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libnetpbm10.
# Preparing to unpack .../24-libnetpbm10_2%3a10.0-15.4_amd64.deb ...
# Unpacking libnetpbm10 (2:10.0-15.4) ...
# Selecting previously unselected package netpbm.
# Preparing to unpack .../25-netpbm_2%3a10.0-15.4_amd64.deb ...
# Unpacking netpbm (2:10.0-15.4) ...
# Setting up imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libwmflite-0.2-7:amd64 (0.2.12-5ubuntu1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up libnetpbm10 (2:10.0-15.4) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up netpbm (2:10.0-15.4) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libdjvulibre-text (3.5.28-2build2) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.4) ...
# Setting up libjxr-tools (1.2~git20170615.f752187-5) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.4) ...
# Setting up libdjvulibre21:amd64 (3.5.28-2build2) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.4) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# #### 1. SGD
#
# Обычный и стохастический градиентный спуск.
#
# $$x_{t + 1} = x_t - \eta v_t,$$
#
# где $v_{t} = \nabla f(x_{t})$ &mdash; аналогия со скоростью.

# %%
def sgd(init_parameters, func_grad, lr, n_iter):
    '''
    Метод оптимизации SGD.

    Параметры:
    - parameters - начальное приближение параметров,
    - func_grad - функция, задающая градиент оптимизируемой функции,
    - lr - скорость обучения,
    - n_iter - количество итераций метода.

    Возвращает историю обновлений параметров.
    '''

    parameters = init_parameters.copy()
    history = [parameters.copy()]

    for i in range(n_iter):
        parameters = parameters - lr*func_grad(parameters)
        history = np.concatenate((history, [parameters.copy()]), axis = 0)

    return history

# %% [markdown]
# #### 2. SGD + Momentum
#
# Сгладим градиент, используя информацию о том, как градиент изменялся раньше.
# Физическая аналогия &mdash; добавляем инерцию.
#
#
# $$x_{t + 1} = x_t + v_{t},$$
# где $v_{t} = \mu v_{t - 1} - \eta \nabla f(x_{t})$ &mdash; сглаживаем градиенты.

# %%
def sgd_momentum(init_parameters, func_grad, lr, mu, n_iter):
    '''
    Метод оптимизации SGD Momentum.

    Параметры:
    - parameters - начальное приближение параметров,
    - func_grad - функция, задающая градиент оптимизируемой функции,
    - lr - скорость обучения,
    - mu - коэффициент сглаживания,
    - n_iter - количество итераций метода.

    Возвращает историю обновлений параметров.
    '''
    parameters = init_parameters.copy()
    history = [parameters.copy()]
    vt = 0

    for i in range(n_iter):
        vt = mu*vt - lr*func_grad(parameters)
        parameters = parameters +  vt
        history = np.concatenate((history, [parameters.copy()]), axis = 0)

    return history

# %% [markdown]
# #### 3. Adagrad
#
# Adagrad &mdash; один из самых первых адаптивных методов оптимизации.
#
# Во всех изученных ранее методах есть необходимость подбирать шаг метода (коэффициент $\eta$). На каждой итерации все компоненты градиента оптимизируемой функции домножаются на одно и то же число $\eta$. Но использовать одно значение $\eta$ для всех параметров не оптимально, так как они имеют различные распределения и оптимизируемая функция изменяется с совершенно разной скоростью при небольших изменениях разных параметров.
#
# Поэтому гораздо логичнее **изменять значение каждого параметра с индивидуальной скоростью**. При этом, *чем c большей степени от изменения параметра меняется значение оптимизируемой функции, тем с меньшей скоростью стоить обновлять этот параметр*. Иначе высок шанс расходимости метода. Получить такой результат удается, если разделить градиент на сумму квадратов скорости изменений параметров.
#
# Пусть $x^{(i)}$ &mdash; $i$-я компонента вектора $x$.
# $$x_{t+1, i} = x_{t, i} - \frac{\eta}{\sqrt{g_{t, i}+\varepsilon}}\cdot \nabla f_i(x_t)$$
# $$g_{t} = g_{t-1} + \nabla f(x_t) \odot \nabla f(x_t)$$
#
#
# В матрично-векторном виде шаг алгоритма можно переписать так:
# $$x_{t+1} = x_{t} - \frac{\eta}{\sqrt{g_{t} + \varepsilon}}\odot \nabla f(x_t).$$
# Здесь $\odot$ обозначает произведение Адамара, т.е. поэлементное перемножение векторов.

# %%
def adagrad(init_parameters, func_grad, lr, eps, n_iter):
    '''
    Метод оптимизации Adagrad.

    Параметры:
    - parameters - начальное приближение параметров,
    - func_grad - функция, задающая градиент оптимизируемой функции,
    - lr - скорость обучения,
    - eps - минимальное значение нормирующего члена,
    - n_iter - количество итераций метода.

    Возвращает историю обновлений параметров.
    '''
    parameters = init_parameters.copy()
    history = [parameters.copy()]
    g = [0,0]

    for iter_id in range(n_iter):
      g = g + func_grad(parameters) * func_grad(parameters)
      parameters = parameters - lr/np.sqrt(g + eps)*func_grad(parameters)
      history = np.concatenate((history, [parameters.copy()]), axis = 0)

    return history

# %% [markdown]
# #### 4. RMSProp
#
# Алгоритм RMSProp основан на той же идее, что и алгоритм Adagrad &mdash; адаптировать learning rate отдельно для каждого параметра $\theta^{(i)}$.  Однако Adagrad имеет серьёзный недостаток. Он с одинаковым весом учитывает квадраты градиентов как с самых первых итераций, так и с самых последних. Хотя, на самом деле, наибольшую значимость имеют модули градиентов на последних нескольких итерациях.
#
# Для этого предлагается использовать **экспоненциальное сглаживание**.
# $$x_{t+1} = x_{t} - \frac{\eta}{\sqrt{g_{t} + \varepsilon}}\odot \nabla f(x_t).$$
# $$g_t = \mu g_{t-1} + (1-\mu) \nabla f(x_t) \odot \nabla f(x_t)$$
#
# Стандартные значения гиперпараметров: $\mu = 0.9, \eta = 0.001$.

# %%
def rmsprop(init_parameters, func_grad, lr, mu, eps, n_iter):
    '''
    Метод оптимизации RMSProp.

    Параметры:
    - parameters - начальное приближение параметров,
    - func_grad - функция, задающая градиент оптимизируемой функции,
    - lr - скорость обучения,
    - mu - коэффициент сглаживания,
    - eps - минимальное значение нормирующего члена,
    - n_iter - количество итераций метода.

    Возвращает историю обновлений параметров.
    '''

    parameters = init_parameters.copy()
    history = [parameters.copy()]
    g = np.array([0.,0.], dtype = float)
    for iter_id in range(n_iter):

        g = mu*g + (1-mu) * func_grad(parameters) * func_grad(parameters)
        parameters = parameters - lr/np.sqrt(g + eps)*func_grad(parameters)
        history = np.concatenate((history, [parameters.copy()]), axis = 0)

    return history

# %% [markdown]
# **5. Adam**
#
# Этот алгоритм совмещает в себе 2 идеи:
# * идею алгоритма Momentum *о накапливании градиента*,
# * идею методов Adadelta и RMSProp *об экспоненциальном сглаживании* информации о предыдущих значениях квадратов градиентов.
#
# Благодаря использованию этих двух идей, метод имеет 2 преимущества над большей частью методов первого порядка, описанных выше:
#
#
# 1. Он обновляет все параметры $\theta$ не с одинаковым `learning rate`, а выбирает для каждого $\theta_i$ индивидуальный `learning rate`, что *позволяет учитывать разреженные признаки с большим весом*.
#
#
# 2. Adam за счёт применения экспоненциального сглаживания к градиенту *работает более устойчиво в окрестности оптимального значения параметра $\theta^*$*, чем методы, использующие градиент в точке $x_t$, не накапливая значения градиента с прошлых шагов.
#
#
# Формулы шага алгоритма выглядят так:
# $$v_{t + 1} = \beta v_{t} + (1-\beta) \nabla f(x_{t})$$
# $$g_t = \mu g_{t-1} + (1-\mu) \nabla f(x_t) \odot \nabla f(x_t)$$
#
# Чтобы эти оценки не были смещёнными, нужно их отнормировать:
# $$\widehat{v}_{t + 1} = \frac{v_{t + 1}}{1-\beta^t},$$
# $$\widehat{g}_t = \frac{g_t}{1-\mu^t}.$$
#
# Тогда получим итоговую формулу шага:
#
# $$x_{t+1} = x_t - \frac{\eta}{\sqrt{\widehat{g}_t + \varepsilon}} \odot \widehat{v}_{t + 1}.$$

# %%
def adam(init_parameters, func_grad, eps, lr, beta, mu,  n_iter):
    '''
    Adam.

    Параметры.
    1) theta0 - начальное приближение theta,
    2) func_grad - функция, задающая градиент оптимизируемой функции,
    3) eps - мин. возможное значение знаменателя,
    4) lr - скорость обучения,
    5) beta - параметр экспоненциального сглаживания,
    6) mu - параметр экспоненциального сглаживания,
    7) n_iter - количество итераций метода.
    '''

    parameters = init_parameters.copy()
    history = [parameters.copy()]
    g = np.array([0.,0.], dtype = float)
    vt = 0

    for iter_id in range(1, n_iter+1):
        vt = beta*vt - (1-beta)*func_grad(parameters)
        g = mu*g + (1-mu) * func_grad(parameters) * func_grad(parameters)
        parameters = parameters + lr/np.sqrt(g/(1-mu**iter_id) + eps)*vt/(1-beta**iter_id)
        history = np.concatenate((history, [parameters.copy()]), axis = 0)

    return history

# %% [markdown]
# Сравнение оптимизаторов будем производить на примере двух функций:
# 1. $f(x, y) = 5*x^2 + y^2$
# 2. $f(x, y) = (x-3)^2 + 8(y-5)^4 + \sqrt{x} + \sin(xy)$
#
# Реализуйте данные функции в ячейке ниже для удобства и читаемости кода.

# %%
def square_sum(x):
    ''' f(x, y) = 5 * x^2 + y^2 '''

    return 5*x[0]**2 +  x[1]**2

def square_sum_grad(x):
    ''' grad f(x, y) = <..> '''

    return 10*x[0] + 2*x[1]


def complex_sum(x):
    ''' f(x, y) = (x-3)^2 + 8(y-5)^4 + sqrt(x) + sin(xy)'''

    return (x[0]-3)**2 + 8*(x[1]-5)**4 + np.sqrt(x[0]) + np.sin(x[0]*x[1])

def complex_sum_grad(x):
    ''' grad f(x, y) = <..> '''

    partial_x = 2*x[0]-6-1/2/np.sqrt(x[0]) + x[1]*np.cos(x[0]*x[1])
    partial_y = 32*(x[1]-5)**3 + x[0]*np.cos(x[0]*x[1])

    return np.array([partial_x, partial_y])

# %% [markdown]
# Создадим директорию, в которой будем хранить визуализацию экспериментов.

# %%
# !rm -rf saved_gifs
# !mkdir saved_gifs

# %% [markdown]
# Напишем функцию, которая будет отрисовывать процесс оптимизации.

# %%
def make_experiment(func, trajectory, graph_title,
                    min_y=-7, max_y=7, min_x=-7, max_x=7):
    '''
    Функция, которая для заданной функции рисует её линии уровня,
    а также траекторию сходимости метода оптимизации.

    Параметры.
    1) func - оптимизируемая функция,
    2) trajectory - траектория метода оптимизации,
    3) graph_name - заголовок графика.
    '''

    fig, ax = plt.subplots(figsize=(10, 8))
    xdata, ydata = [], []
    ln, = plt.plot([], [])

    mesh_x = np.linspace(min_x, max_x, 300)
    mesh_y = np.linspace(min_y, max_y, 300)
    X, Y = np.meshgrid(mesh_x, mesh_y)
    Z = np.zeros((len(mesh_x), len(mesh_y)))

    for coord_x in range(len(mesh_x)):
        for coord_y in range(len(mesh_y)):
            Z[coord_y, coord_x] = func(
                np.array((mesh_x[coord_x],
                          mesh_y[coord_y]))
            )

    def init():
        ax.contour(
            X, Y, np.log(Z),
            np.log([0.5, 10, 30, 80, 130, 200, 300, 500, 900]),
            cmap='winter'
        )
        ax.set_title(graph_title)
        return ln,

    def update(frame):
        xdata.append(trajectory[frame][0])
        ydata.append(trajectory[frame][1])
        ln.set_data(xdata, ydata)
        return ln,

    ani = FuncAnimation(
        fig, update, frames=range(len(trajectory)),
        init_func=init, repeat=True
    )
    writer = ImageMagickFileWriter(fps=10)
    ani.save(f'saved_gifs/{graph_title}.gif',
             writer=writer)
    plt.show()

# %% [markdown]
# ### Простая функция $f(x, y) = x^2 + y^2$

# %%
parameters = np.array((5, 5), dtype=float)
func_name = '$f(x, y) = 5x^2 + y^2$'
func_grad = square_sum_grad
func = square_sum
n_iter = 100

# %% [markdown]
# **SGD**

# %%
sgd_trajectory = sgd(
    init_parameters=parameters,
    func_grad=func_grad,
    lr=0.01,
    n_iter=n_iter
)
graph_title = 'Траектория SGD, ' + func_name
make_experiment(
    func,
    sgd_trajectory,
    graph_title,
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **SGD Momentum**

# %%
sgd_momentum_trajectory = sgd_momentum(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.01,
    n_iter=n_iter,
    mu=0.9
)
graph_title = 'Траектория SGD Momentum, ' + func_name
make_experiment(
    func,
    sgd_momentum_trajectory,
    graph_title,
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **Adagrad**

# %%
adagrad_trajectory = adagrad(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.1,
    n_iter=n_iter,
    eps=1e-6,
)
graph_title = 'Траектория Adagrad, ' + func_name
make_experiment(
    func,
    adagrad_trajectory,
    graph_title,
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **RMSProp**

# %%
rmsprop_trajectory = rmsprop(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.1,
    n_iter=n_iter,
    eps=1e-6,
    mu=0.9
)
graph_title = 'Траектория RMSProp, ' + func_name
make_experiment(
    func,
    rmsprop_trajectory,
    graph_title,
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **Adam**

# %%
adam_trajectory = adam(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.1,
    n_iter=n_iter,
    eps=1e-6,
    mu=0.9,
    beta=0.9
)
graph_title = 'Траектория Adam, ' + func_name
make_experiment(
    func,
    adam_trajectory,
    graph_title,
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **Вывод**

# %% [markdown]
# ### Сложная функция $f(x, y) = (x-3)^2 + 8(y-5)^4 + \sqrt{x} + \sin(xy)$

# %%
parameters = np.array((5, -2), dtype=float)
func_name = '$f(x, y) = (x-3)^2 + 8(y-5)^4 + \sqrt{x} + \sin(xy)$'
func_grad = complex_sum_grad
func = complex_sum
n_iter = 100

# %% [markdown]
# **SGD**

# %%
sgd_trajectory = sgd(
    init_parameters=parameters,
    func_grad=func_grad,
    lr=0.0002,
    n_iter=n_iter
)
graph_title = 'Траектория SGD, ' +  func_name
make_experiment(
    func,
    sgd_trajectory,
    graph_title,
    -5, 10, 0, 10
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **SGD Momentum**

# %%
sgd_momentum_trajectory = sgd_momentum(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.0002,
    n_iter=n_iter,
    mu=0.7
)
graph_title = 'Траектория SGD Momentum, ' +  func_name
make_experiment(
    func,
    sgd_momentum_trajectory,
    graph_title,
    -5, 10, 0, 10
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **Adagrad**

# %%
adagrad_trajectory = adagrad(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.1,
    n_iter=n_iter,
    eps=1e-6,
)
graph_title = 'Траектория Adagrad, ' + func_name
make_experiment(
    func,
    adagrad_trajectory,
    graph_title,
    -5, 10, 0, 10
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **RMSProp**

# %%
rmsprop_trajectory = rmsprop(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.1,
    n_iter=n_iter,
    eps=1e-6,
    mu=0.9
)
graph_title = 'Траектория RMSProp, ' + func_name
make_experiment(
    func,
    rmsprop_trajectory,
    graph_title,
    -5, 10, 0, 10
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **Adam**

# %%
adam_trajectory = adam(
    init_parameters=parameters.copy(),
    func_grad=func_grad,
    lr=0.1,
    n_iter=n_iter,
    eps=1e-6,
    mu=0.9,
    beta=0.9
)
graph_title = 'Траектория Adam, ' + func_name
make_experiment(
    func,
    adam_trajectory,
    graph_title,
    -5, 10, 0, 10
)
clear_output()
Image(open(f'saved_gifs/{graph_title}.gif','rb').read())

# %% [markdown]
# **Вывод**

# %% [markdown]
# SGD Работает, долгая сходимость на сложной функции
#
# SGD + momentum сходится быстрее, но появилась проблема перескакивания минимума из-за большой скорости затухания ($\mu$)
#
# AdaGrad затухание сходимости из-за неограниченного роста g, который находится в знаменателе
#
# MRSProp Быстро сходится, не затухает. На гифке для сложного примера в конце есть какое-то странное колебание, что можно решить накапливанием градиента(то есть как сделано в adam)
#
# Adam Ну просто супер
