# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_mipt.html">Phystech@DataScience</a>
# ## Семинар 4
# ## Сегментация

# %%
import torch
import torchvision

from torch import nn
from torch.utils.data import Dataset, DataLoader, RandomSampler, random_split
from torch.nn import BCEWithLogitsLoss
import numpy as np

import torchvision.transforms as tt
from PIL import Image
import os

import matplotlib.pyplot as plt

from tqdm import tqdm
from IPython.display import clear_output # для отчистки экрана

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
device = f"cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(device)
# Out:
# cuda

# %% [markdown]
# ## 1. Релизация метрики IoU
# Реализуйте метрику IoU. Она вам понадобится далее для оценивания результатов предсказания модели.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def iou(predicted_mask_batch, target_mask_batch):
    """ Считает среднее IoU для всех элементов батча
    predicted_mask_batch - булев тензор размерности (batch_size, 1, H, W) - определяет предсказанную принадлежность пикселя к классу 1
    target_mask_batch - булев тензор размерности (batch_size, 1, H, W) - определяет реальную принадлежность пикселя к классу 1
    """
    # Площадь пересечения в пикселях для всех элементов батча
    intersection = (predicted_mask_batch & target_mask_batch).sum(axis = (1,2,3))
    # Площадь объединения в пикселях для всех элементов батча
    union =  (predicted_mask_batch | target_mask_batch).sum(axis = (1,2,3))
    # Посчитайте IoU для каждого элемента батча, а затем усредните по батчу
    iou = (intersection/union).mean()
    return iou

# %%
predicted_mask_batch = torch.ones((1, 1, 10, 10)).bool()
target_mask_batch =  torch.ones((1, 1, 10, 10)).bool()
assert torch.allclose(iou(predicted_mask_batch, target_mask_batch), torch.tensor(1.0))

# %% [markdown]
# ## 2. Сегментация изображений

# %% [markdown]
# Попробуем написать неглубокую сеть и сегментировать ногти на изображения ладоней. Для этого напишем энкодер, который будет применять к входному изображению несколько свёрток, а затем напишем декодер, который по скрытому представлению будет разворачивать картинку с помощью обратных свёрток.

# %% [markdown]
# Загрузите скачанный [архив](https://drive.google.com/u/0/uc?id=1Irfwzmx7b1m2jwd2lHGDO1vXOgUeBBb0&export=download) `archive.zip` в Colab.

# %%
import gdown # библиотека для скачивания файлов с гугл-диска

gdown.download('https://drive.google.com/u/0/uc?id=1Irfwzmx7b1m2jwd2lHGDO1vXOgUeBBb0&export=download')
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1Irfwzmx7b1m2jwd2lHGDO1vXOgUeBBb0&export=download
# To: /content/archive.zip
# 100%|██████████| 32.5M/32.5M [00:00<00:00, 81.1MB/s]
# 'archive.zip'

# %%
! unzip archive.zip # разархивируем наши данные
# Out:
# Archive:  archive.zip
#    creating: archive/
#   inflating: __MACOSX/._archive
#    creating: archive/images/
#   inflating: __MACOSX/archive/._images
#    creating: archive/nails_segmentation/
#   inflating: __MACOSX/archive/._nails_segmentation
#   inflating: archive/Copy_of_[hw]gan.ipynb
#   inflating: __MACOSX/archive/._Copy_of_[hw]gan.ipynb
#    creating: archive/labels/
#   inflating: __MACOSX/archive/._labels
#   inflating: archive/hw_segmentation.ipynb
#   inflating: __MACOSX/archive/._hw_segmentation.ipynb
#   inflating: archive/images/d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: __MACOSX/archive/images/._d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: archive/images/bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: __MACOSX/archive/images/._bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: archive/images/34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: __MACOSX/archive/images/._34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: archive/images/4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: __MACOSX/archive/images/._b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: archive/images/4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: __MACOSX/archive/images/._3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: archive/images/09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: archive/images/2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: __MACOSX/archive/images/._2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: archive/images/ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: __MACOSX/archive/images/._ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: archive/images/4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: __MACOSX/archive/images/._4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: archive/images/da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: __MACOSX/archive/images/._da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: archive/images/af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: __MACOSX/archive/images/._af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: archive/images/5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: __MACOSX/archive/images/._5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: archive/images/917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: __MACOSX/archive/images/._917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: archive/images/C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: __MACOSX/archive/images/._C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: archive/images/54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: __MACOSX/archive/images/._54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: archive/images/feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: __MACOSX/archive/images/._feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: archive/images/4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: __MACOSX/archive/images/._2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: archive/images/865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: __MACOSX/archive/images/._865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: archive/images/4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: __MACOSX/archive/images/._a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: archive/images/d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: __MACOSX/archive/images/._7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: archive/images/5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: __MACOSX/archive/images/._5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: archive/images/d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: __MACOSX/archive/images/._1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: archive/images/4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: __MACOSX/archive/images/._869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: archive/images/edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: __MACOSX/archive/images/._edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: archive/images/41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: __MACOSX/archive/images/._41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: archive/images/9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: __MACOSX/archive/images/._9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: archive/images/d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: __MACOSX/archive/images/._cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: archive/images/964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: __MACOSX/archive/images/._964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: archive/images/4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/images/F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: __MACOSX/archive/images/._F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: archive/images/4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/images/d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/images/._d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#    creating: archive/nails_segmentation/images/
#   inflating: __MACOSX/archive/nails_segmentation/._images
#    creating: archive/nails_segmentation/labels/
#   inflating: __MACOSX/archive/nails_segmentation/._labels
#   inflating: archive/labels/d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: __MACOSX/archive/labels/._d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: archive/labels/bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: __MACOSX/archive/labels/._bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: archive/labels/34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: __MACOSX/archive/labels/._34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: archive/labels/4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: __MACOSX/archive/labels/._b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: archive/labels/4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: __MACOSX/archive/labels/._3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: archive/labels/09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: archive/labels/2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: __MACOSX/archive/labels/._2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: archive/labels/ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: __MACOSX/archive/labels/._ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: archive/labels/4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: __MACOSX/archive/labels/._4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: archive/labels/da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: __MACOSX/archive/labels/._da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: archive/labels/af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: __MACOSX/archive/labels/._af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: archive/labels/5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: __MACOSX/archive/labels/._5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: archive/labels/917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: __MACOSX/archive/labels/._917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: archive/labels/C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: __MACOSX/archive/labels/._C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: archive/labels/54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: __MACOSX/archive/labels/._54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: archive/labels/feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: __MACOSX/archive/labels/._feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: archive/labels/4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: __MACOSX/archive/labels/._2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: archive/labels/865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: __MACOSX/archive/labels/._865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: archive/labels/4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: __MACOSX/archive/labels/._a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: archive/labels/d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: __MACOSX/archive/labels/._7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: archive/labels/5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: __MACOSX/archive/labels/._5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: archive/labels/d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: __MACOSX/archive/labels/._1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: archive/labels/4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: __MACOSX/archive/labels/._869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: archive/labels/edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: __MACOSX/archive/labels/._edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: archive/labels/41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: __MACOSX/archive/labels/._41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: archive/labels/9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: __MACOSX/archive/labels/._9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: archive/labels/d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: __MACOSX/archive/labels/._cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: archive/labels/964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: __MACOSX/archive/labels/._964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: archive/labels/4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/labels/F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: __MACOSX/archive/labels/._F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: archive/labels/4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/labels/d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/labels/._d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: archive/nails_segmentation/images/bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: archive/nails_segmentation/images/34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: archive/nails_segmentation/images/4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: archive/nails_segmentation/images/4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: archive/nails_segmentation/images/09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: archive/nails_segmentation/images/ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: archive/nails_segmentation/images/4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: archive/nails_segmentation/images/da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: archive/nails_segmentation/images/af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: archive/nails_segmentation/images/5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: archive/nails_segmentation/images/917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: archive/nails_segmentation/images/C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: archive/nails_segmentation/images/54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: archive/nails_segmentation/images/feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: archive/nails_segmentation/images/4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: archive/nails_segmentation/images/865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: archive/nails_segmentation/images/4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: archive/nails_segmentation/images/d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: archive/nails_segmentation/images/5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: archive/nails_segmentation/images/d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: archive/nails_segmentation/images/4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: archive/nails_segmentation/images/edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: archive/nails_segmentation/images/41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: archive/nails_segmentation/images/9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: archive/nails_segmentation/images/d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: archive/nails_segmentation/images/964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: archive/nails_segmentation/images/4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: archive/nails_segmentation/images/4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/images/d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/images/._d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d97db2d2-18ff-456d-8d85-23bfb7109aef.jpg
#   inflating: archive/nails_segmentation/labels/bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._bf93c2e2-7b5f-4108-ae85-4ef68564d418.jpg
#   inflating: archive/nails_segmentation/labels/34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._34404E67-4BB8-432E-863E-C1BEF5EB37E0.jpg
#   inflating: archive/nails_segmentation/labels/4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c490eae-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d61a32a0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._b25b81b1-d562-4891-ae4f-83a82a2b64b5.jpg
#   inflating: archive/nails_segmentation/labels/4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c4a6402-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._3493127D-7B19-4E50-94AE-2401BD2A91C8.jpg
#   inflating: archive/nails_segmentation/labels/09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._09aefeec-e05f-11e8-87a6-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._2C29D473-CCB4-458C-926B-99D0042161E6.jpg
#   inflating: archive/nails_segmentation/labels/ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._ABD5AB5C-E7CA-4420-A983-2161029ECC9E.jpg
#   inflating: archive/nails_segmentation/labels/4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c478f3e-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c472e18-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4252e46c-e40f-4543-91ab-031917d46c5c.jpg
#   inflating: archive/nails_segmentation/labels/da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._da236f3a-8c82-4c64-9a7d-9b950fd8b47e.jpg
#   inflating: archive/nails_segmentation/labels/af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._af5626a5-feb4-4b2a-8c57-152e443ea3dc.jpg
#   inflating: archive/nails_segmentation/labels/5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._5fad3947-76d7-4352-9329-4a92f898dd59.jpg
#   inflating: archive/nails_segmentation/labels/917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._917FB1CC-E132-497F-A463-46C61A84BB40.jpg
#   inflating: archive/nails_segmentation/labels/C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._C03527E3-ADED-423E-9F11-D797EA35E286.jpg
#   inflating: archive/nails_segmentation/labels/54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._54108996-6DA8-48F9-93DF-7ABB92F64E03.jpg
#   inflating: archive/nails_segmentation/labels/feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._feb2c029-b89c-4ce5-b208-db2114516a40.jpg
#   inflating: archive/nails_segmentation/labels/4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c47ee66-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._2c376c66-9823-4874-869e-1e7f5c54ec7b.jpg
#   inflating: archive/nails_segmentation/labels/865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._865a1e90-7ad2-4ceb-b2a1-50b07875c5c7.jpg
#   inflating: archive/nails_segmentation/labels/4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c484f8c-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c4a0dd6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d60153c0-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._a3a73edd-1483-4413-addb-9a7264b5d853.jpg
#   inflating: archive/nails_segmentation/labels/d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d60f3ecc-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d6072ec6-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._7e9f5818-4425-4d8a-808a-4673d96fa250.jpg
#   inflating: archive/nails_segmentation/labels/5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._5CBCC5AC-B638-4DFA-AA7B-2464FADFF2F7.jpg
#   inflating: archive/nails_segmentation/labels/d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d63890ec-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d60a5f06-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d6358550-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d633f320-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d62b0cd8-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._1eecab90-1a92-43a7-b952-0204384e1fae.jpg
#   inflating: archive/nails_segmentation/labels/4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c46b91a-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._869CDA2E-8251-4880-89D6-9409CBC416F3.jpg
#   inflating: archive/nails_segmentation/labels/edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._edff1324-0b02-4471-b449-14cea27f0094.jpg
#   inflating: archive/nails_segmentation/labels/41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._41d83dbb-7c39-4d91-979e-eec5ff71b265.jpg
#   inflating: archive/nails_segmentation/labels/9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._9ABD7CB9-7617-4A66-8892-B335FDB0E89F.jpg
#   inflating: archive/nails_segmentation/labels/d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d6303a64-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._cc25f453-04ca-4c24-92bc-f26c5a94e78c.jpg
#   inflating: archive/nails_segmentation/labels/964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._964c11f9-fbe3-420e-8674-9bb356cb5d3f.jpg
#   inflating: archive/nails_segmentation/labels/4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c48acb6-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d639e532-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d6321726-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._F6F9B3E6-FA7B-4DAC-B08C-1AD19BC43A76.jpg
#   inflating: archive/nails_segmentation/labels/4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._4c49b502-e402-11e8-97db-0242ac1c0002.jpg
#   inflating: archive/nails_segmentation/labels/d61d6de4-db67-11e8-9658-0242ac1c0002.jpg
#   inflating: __MACOSX/archive/nails_segmentation/labels/._d61d6de4-db67-11e8-9658-0242ac1c0002.jpg

# %% [markdown]
# Посмотрим на наши данные. Для этого напишем класс датасета:

# %%
class NailsDataset(torch.utils.data.Dataset):
    def __init__(self, root, ids=None):
        # выполняем отнаследованную часть функции инициализации
        super(NailsDataset, self).__init__()

        transform = tt.Compose(
            [tt.ToTensor(),
            tt.Resize((128, 128))
        ]) # приведём все картинки к одному размеру (128, 128) и переведём их в тензоры

        if ids is not None:
            imgs_files = np.array(os.listdir(f'{root}/images'))[ids] # считаем список файлов изображений
            msks_files = np.array(os.listdir(f'{root}/labels'))[ids] # считаем список файлов масок

        else:
            imgs_files = os.listdir(f'{root}/images')
            msks_files = os.listdir(f'{root}/labels')

        # откроем изображения как PIL картинки в формате RGB и применим трансформацию
        self.imgs = [transform(Image.open(f'{root}/images/{file}').convert('RGB'))
                        for file in imgs_files]

        # откроем маски как PIL картинки в формате ч/б и применим трансформацию
        self.msks = [transform(Image.open(f'{root}/labels/{file}').convert('L'))
                        for file in msks_files]

    def __len__(self):
        return len(self.imgs) # возвращает размер датасета

    def __getitem__(self, id):
        # возвращает картинку и соответсвующую ей маску в виде тензоров
        return self.imgs[id], self.msks[id]

# %%
root = '/content/archive'

ids = np.arange(0, len(os.listdir(f'{root}/images')))

train_ids, test_ids = np.split(np.random.permutation(ids),
                               [int(0.8 * len(ids))])

# %%
dataset = NailsDataset(root)

train_data =  NailsDataset(root,train_ids)# создадим тренировочный датасет
test_data =  NailsDataset(root,test_ids)# создадим валидационный датасет
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# Сколько изображений в каждом из полученных датасетов?

# %%
print(train_data.__len__())
print(test_data.__len__())
# Out:
# 41
# 11

# %% [markdown]
# **Ответ**:
#
# 41
# 11

# %% [markdown]
# Визуализируем изображения и соответствующие маски.

# %%
plt.figure(figsize=(10, 4))

for i in range(5):
    plt.subplot(2, 5, i + 1)
    # приводим тензор в numpy.ndarray
    # переставляем первое измерение каналов на последнее мето для отрисовки в plt
    plt.imshow(test_data[i][0].detach().cpu().numpy().transpose(1, 2, 0))
    plt.axis('off')

    plt.subplot(2, 5, i + 6)
    # приводим тензор в numpy.ndarray
    # сплющиваем его для отображения в ч/б формате
    plt.imshow(test_data[i][1].detach().cpu().squeeze(0).numpy(), cmap='gray')
    plt.axis('off')

plt.show()

# %% [markdown]
# Теперь мы, наконец, готовы перейти к написанию энкодера!
#
# Напишем энкодер с тремя слоями свёрток, на каждом слое будем уменьшать вдвое размер изображения.
#
# *Подсказка: для получения нужных размеров изображений подберите подходящие разумные значения размера фильтра, padding и stride.*

# %%
from torch.nn.modules.batchnorm import BatchNorm2d
class Encoder(torch.nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()

        self.conv1 = torch.nn.Sequential(
            nn.Conv2d(kernel_size = 3, padding = 1, stride = 2, in_channels = 3, out_channels=32),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32)
        ) # на вход получаем изображение 128x128x3, на выходе после свертки, функции активации и батч-нормализации - 64x64x32

        self.conv2 = torch.nn.Sequential(
            nn.Conv2d(kernel_size = 3, padding = 1, stride = 2, in_channels = 32, out_channels=64),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=64)
        ) # на вход получаем изображен 64x64x32, на выходе после свертки, функции активации и батч-нормализации - 32x32x64

        self.conv3 = torch.nn.Sequential(
            nn.Conv2d(kernel_size = 3, padding = 1, stride = 2, in_channels = 64, out_channels=128),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=128)
        ) # на вход получаем изображен 32x32x64, на выходе после свертки, функции активации и батч-нормализации - 16x16x128

    def forward(self, x):
        x = self.conv1(x) # 64 х 64
        x = self.conv2(x) # 32 х 32
        x = self.conv3(x) # 16 х 16
        return x

# %% [markdown]
# Посмотрим на работу нашего энкодера на примере.

# %%
x = train_data[0][0].unsqueeze(0)

# %%
enc = Encoder()

z = enc(x)
z.shape
# Out:
# torch.Size([1, 128, 16, 16])

# %% [markdown]
# С помощью операции обратной свёртки напишем декодер из трёх слоёв, на каждом из которых размер картинки на выходе будет соответствовать картинке в энкодере. Не забудем добавить нормализацию как в обычной сверточной сети. На выходе последнего слоя добавим сигмоиду для дальнейшего подсчёта бинарной крсс-энтропии.

# %%
class Decoder(torch.nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        self.convt1 = torch.nn.Sequential(
            nn.ConvTranspose2d(kernel_size = 2, stride = 2, in_channels = 128, out_channels=64),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(num_features=64)
        ) # 16x16x128 -> 32x32x64

        self.convt2 = torch.nn.Sequential(
            nn.ConvTranspose2d(kernel_size = 2, stride = 2, in_channels = 64, out_channels=32),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(num_features=32)
        )  # 32x32x64 -> 64x64x32

        self.convt3 = torch.nn.Sequential(
            nn.ConvTranspose2d(kernel_size = 2, stride = 2, in_channels = 32, out_channels=1),
            torch.nn.Sigmoid()
        )  # 64x64x32 -> 128x128x1

    def forward(self, z, test=False):
        z = self.convt1(z)
        if test:
            print(z.shape)

        z = self.convt2(z)
        if test:
            print(z.shape)

        z = self.convt3(z)
        if test:
            print(z.shape)

        return z

# %% [markdown]
# Проверяем работу.

# %%
dec = Decoder()

dec(z, test=True);
# Out:
# torch.Size([1, 64, 32, 32])
# torch.Size([1, 32, 64, 64])
# torch.Size([1, 1, 128, 128])

# %% [markdown]
# Соединяем всё в одну сеть и запустим процесс обучения.

# %%
class Segmentation(torch.nn.Module):
    def __init__(self):
        super(Segmentation, self).__init__()
        self.enc = Encoder()
        self.dec = Decoder()

    def forward(self, x):
        z = self.enc(x)
        res = self.dec(z)
        return res

# %%
# создаём загрузчик
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=32)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=32)

# %%
model = Segmentation() # создаём экземпляр модели
model = model.to(device) # перемещаем модель

# %% [markdown]
# Поскольку выход сети будет говорить для каждого пикселя вероятность быть частью маски (насколько пиксель белый), то в качестве функции потерь возьмём попиксельную кросс-энтропию.

# %%
lr = 1e-3

# создаём оптимизатор
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# задаём функцию потерь
criterion = nn.BCELoss().to(device)

# %% [markdown]
# Напишем функцию для визуализации процесса обучения. Она будет выводить три ряда картинок: изображение, его маску и предсказанную моделью маску.

# %%
def show_res(res, epoch, max_epoch):
    """
    Отображение процесса обучения

    res - предсказанные маски
    epoch - текущая эпоха
    max_epoch - всего эпох
    """

    plt.figure(figsize=(6, 4))
    for i in range(5):
        plt.subplot(3, 5, i + 1)
        # рисуем картинку
        plt.imshow(test_data[i][0].detach().cpu().numpy().transpose(1, 2, 0))
        plt.axis('off')

        plt.subplot(3, 5, i + 6)
        # рисуем маску
        plt.imshow(test_data[i][1].detach().cpu().squeeze(0).numpy(), cmap='gray')
        plt.axis('off')

        plt.subplot(3, 5, i + 11)
        # рисуем  предсказанную маску
        plt.imshow(res[i].detach().cpu().squeeze(0).numpy(), cmap='gray')
        plt.axis('off')

    plt.suptitle(f'Epoch {epoch + 1}/{max_epoch}')
    plt.show()

# %%
def plot_loss_iou(train_loss, val_loss, train_iou, val_iou):
    fig, ax = plt.subplots(figsize=(12, 6), ncols=2)
    ax[0].set_title('Loss on train and validation')

    ax[0].plot(train_loss, label='train')
    ax[0].plot(val_loss, label='test')

    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')

    ax[1].set_title('IoU on train and validation')

    ax[1].plot(train_iou, label='train')
    ax[1].plot(val_iou, label='test')

    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('IoU')

    plt.legend()
    plt.show()

# %% [markdown]
# Напишем самую главную функцию, отвечающую за наш процесс обучения, и запустим обучение на 35 эпох.

# %%
def train_loop(model, test_data,
               train_dataloader, test_dataloader, max_epoch=10):
    pbar = tqdm(range(max_epoch),
                desc=f'train_loss=nan, val_loss=nan')

    train_losses = []
    val_losses = []
    train_iou = []
    val_iou = []

    for epoch in pbar:
        model.train() # переводим модель в режим обучения
        train_loss = []
        train_iou_ = []

        for x, y in train_dataloader:
            x = x.to(device) # переносим данные на видеокарту
            y = y.to(device)

            predicted_proba = model(x) # запускаем модель

            loss = criterion(predicted_proba, y) # считаем лосс
            train_loss.append(loss.detach().cpu().numpy().item())

            predicted_mask = (predicted_proba > 0.5).bool()
            target_mask = y.bool()
            batch_iou = iou(predicted_mask, target_mask)
            train_iou_.append(batch_iou.detach().cpu().numpy())

            # СДЕЛАЙТЕ ШАГ ОПТИМИЗАЦИИ
            # Обратный проход
            loss.backward()
            # Шаг градиента
            optimizer.step()
            # Зануляем градиенты
            optimizer.zero_grad()

        train_losses.append(np.mean(train_loss))
        train_iou.append(np.mean(train_iou_))

        model.eval() # переводим модель в режим инференса
        val_loss = []
        val_iou_ = []

        with torch.no_grad(): # не накпливаем градиенты
            for x, y in test_dataloader:
                x = x.to(device) # переносим данные на видеокарту
                y = y.to(device)

                # ПОСЧИТАЙТЕ ЛОСС И IOU на валидации

                predicted_proba = model(x) # запускаем модель

                loss = criterion(predicted_proba, y) # считаем лосс
                train_loss.append(loss.detach().cpu().numpy().item())

                predicted_mask = (predicted_proba > 0.5).bool()
                target_mask = y.bool()
                batch_iou = iou(predicted_mask, target_mask)


                val_loss.append(loss.detach().cpu().numpy())
                val_iou_.append(batch_iou.detach().cpu().numpy())


            val_losses.append(np.mean(val_loss))
            val_iou.append(np.mean(val_iou_))

            res = []
            if (epoch % 5 == 0) or (epoch == max_epoch - 1):
                for i in range(5):
                    # предсказываем маски для первых пяти картинок
                    res.append(model(test_data[i][0].unsqueeze(0).cuda()).squeeze(0))

                clear_output(wait=True)
                show_res(res, epoch, max_epoch) # отрисовываем результат

        pbar.set_description(f'train_loss={np.mean(train_loss)}, val_loss={np.mean(val_loss)}, train_iou={np.mean(train_iou_)}, val_iou={np.mean(val_iou_)}')

    return train_losses, val_losses, train_iou, val_iou

# %%
train_losses, val_losses, train_iou, val_iou = train_loop(model, test_data,
                                      train_dataloader, test_dataloader,
                                      max_epoch=135)
plot_loss_iou(train_losses, val_losses, train_iou, val_iou)
# Out:
# train_loss=0.2506705621878306, val_loss=0.6501163244247437, train_iou=0.7869436740875244, val_iou=0.16078528761863708: 100%|██████████| 135/135 [00:19<00:00,  7.01it/s]

# %% [markdown]
# Каких результатов удалось достичь с помощью неглубокой сети? Напишите вывод по графику и примерам изображения.

# %% [markdown]
# **Вывод**:
#
# Хотелось бы значение метрики IoU ~ 1, но этого не получается. IoU мало меняется после 40 эпохи.

# %% [markdown]
# ## 3. Реализация модели U-Net

# %% [markdown]
# Реализуйте модель U-Net ниже, дописав пропущенные части кода.

# %%
def conv_bn_relu(in_channels, out_channels, kernel=3, stride=1, padding=1):
    net = nn.Sequential(
        nn.Conv2d(in_channels, out_channels,
                  kernel_size=kernel, stride=stride, padding=padding),
        nn.BatchNorm2d(num_features=out_channels),
        nn.ReLU(inplace=True)
    )
    return net


class Stacked2ConvsBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Stacked2ConvsBlock, self).__init__()
        self.blocks = nn.Sequential(
            conv_bn_relu(in_channels, out_channels),
            conv_bn_relu(out_channels, out_channels)
        )

    def forward(self, net):
        net = self.blocks(net)
        return net


class UpSamplingBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UpSamplingBlock, self).__init__()

        # Понижаем число каналов
        self.upsample = nn.ConvTranspose2d(
            in_channels, in_channels, kernel_size=2, stride=2)

        # Стакаем с симметричным слоем из левой половины "U".
        # Число каналов входной карты при этом удваивается.
        self.convolve = Stacked2ConvsBlock(2 * in_channels, out_channels)

    def forward(self, left_net, right_net):
        right_net = self.upsample(right_net)
        # конкатенируем векторы из левой и правой половины
        net = <ваш код>
        np.concatenate(left_net, right_net)
        # применяем свертку
        net = <ваш код>
        nn.Conv2D()
        return net


class DownSamplingBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DownSamplingBlock, self).__init__()
        self.blocks = nn.Sequential(
            nn.MaxPool2d(2, 2),
            Stacked2ConvsBlock(in_channels, out_channels)
        )

    def forward(self, net):
        return self.blocks(net)


class Unet(nn.Module):
    def __init__(self):
        super(Unet, self).__init__()
        self.init_conv = Stacked2ConvsBlock(3, 64)

        self.downsample_1 = DownSamplingBlock(64, 128)
        self.downsample_2 = DownSamplingBlock(128, 256)
        self.downsample_3 = DownSamplingBlock(256, 512)
        self.downsample_4 = DownSamplingBlock(512, 1024)

        # В середине есть блок без пары с 1024 каналами
        # с ним конкатенировать некого, потому просто свернём его
        self.upconv = Stacked2ConvsBlock(1024, 512)

        # Подъём. Аналогично.
        self.upsample_1 = UpSamplingBlock(512, 256)
        self.upsample_2 = UpSamplingBlock(256, 128)
        self.upsample_3 = UpSamplingBlock(128, 64)
        # Чтобы учесть входной слой после самой первой свёртки и согласовать размерности
        self.upsample_4 = UpSamplingBlock(64, 64)

        # Предсказание
        self.agg_conv = nn.Sequential(nn.Conv2d(64, 1, kernel_size=1), nn.Sigmoid())

    def forward(self, x):
        net0 = self.init_conv(x) # 3 --> 64

        net1 = self.downsample_1(net0) # 64 --> 128
        net2 = self.downsample_2(net1) # 128 --> 256
        net3 = self.downsample_3(net2) # 256 --> 512
        net = self.downsample_4(net3) # 512 --> 1024

        net = self.upconv(net) # 1024 --> 512

        net = self.upsample_1(net3, net) # 512 --> 256
        net = <ваш код> # 256 --> 128
        net = <ваш код> # 128 --> 64
        net = <ваш код> # 64 --> 64

        net = self.agg_conv(net) # 64 --> 1

        return net

# %% [markdown]
# ### Обучение модели
#
# Обучите полученную модель U-Net на датасете ногтей. Постройте аналогичные графики лосса и метрики качества. Выведите несколько изображений и полученных для них масок. Сравните результаты с сетью, построенной в предыдущем пункте задания.

# %%
unet_model = Unet().to(device)

lr = 1e-4

# создаём оптимизатор
optimizer = <задайте оптимизатор>

# задаём функцию потерь
criterion = <задайте функцию потерь>


# создаём оптимизатор
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# задаём функцию потерь
criterion = nn.BCELoss().to(device)

# %%
train_losses, val_losses, train_iou, val_iou = train_loop(unet_model, test_data,
                                      train_dataloader, test_dataloader,
                                      max_epoch=35)
plot_loss_iou(train_losses, val_losses, train_iou, val_iou)

# %% [markdown]
# Сделайте выводы.

# %% [markdown]
# **Вывод**
